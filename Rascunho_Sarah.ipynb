# %% [markdown]
# <a href="https://colab.research.google.com/github/orafaelvinicius/ada_tech_logica_ii_g2/blob/main/Rascunho_Sarah.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 💻 Rascunho Sarah
#
# Não se esqueça de realizar **upload** do Arquivo [Json](https://github.com/SarahFeanor/ada_tech_logica_ii_g2/blob/main/projetoModuloII.json), o programa não funcionará sem o arquivo no notebook.

# %%
# Importando Bibliotecas necessárias
import json

# Opções do Menu principal e Submenu do programa:
menu_principal = """
\nBem vindo ao nosso Sistema
\nCadastramento de Usuários:

1 - Inserir usuário
2 - Excluir usuário
3 - Atualizar usuário
4 - Informações de um usuário
5 - Informações de todos os usuários
6 - Sair\n
"""

sub_menu_principal = """
\nQual informação deseja alterar?
1 - Nome
2 - Telefone
3 - Endereço
\n
"""

# Função 1 - Lê e salva arquivos:
def ler_salvar_arquivo(ler=True, nome_arquivo='projetoModuloII.json', cadastros=None):
    if ler:
        try:
            with open(nome_arquivo, 'r', encoding='utf-8') as arquivo:  # lembrar de setar o enconding para utf-8
                return json.load(arquivo)
        except FileNotFoundError:
            return {}

    with open(nome_arquivo, 'w') as arquivo:
        json.dump(cadastros, arquivo)


# Função 2 - Adiciona um novo usuário aos cadastros:
def add_usuario(cadastros, nome, telefone="Não Informado", endereco="Não Informado"):
    for usuario in cadastros.values():
        if usuario['Nome'] == nome and usuario['Telefone'] == telefone and usuario['Endereço'] == endereco and not usuario['Status']:
            usuario['Status'] = True
            return cadastros

    novo_id = 1
    if cadastros:
        novo_id = max(int(key) for key in cadastros) + 1

    novo_usuario = {
        'Status': True,
        'Nome': nome,
        'Telefone': telefone,
        'Endereço': endereco
    }

    cadastros[str(novo_id)] = novo_usuario
    print(f"Usuário adicionado com sucesso! ID do novo usuário: {novo_id}")
    return cadastros

# Função 3 - Exclui as informações de um usuário:
def excluir_usuario(cadastros, *ids):
    for id in ids:
        if str(id) in cadastros:
            cadastros[str(id)]['Status'] = False
        else:
            print(f"Usuário com ID {id} não encontrado!")

    ler_salvar_arquivo(ler=False, nome_arquivo='projetoModuloII.json', cadastros=cadastros)
    return cadastros

# Função 4 - Edita as informações do usuário:
def editar_usuario(cadastros, id, campo, novo_valor):
    if str(id) in cadastros:
        if campo == 1:
            cadastros[str(id)]['Nome'] = novo_valor
        elif campo == 2:
            cadastros[str(id)]['Telefone'] = novo_valor
        elif campo == 3:
            cadastros[str(id)]['Endereço'] = novo_valor
    else:
        print(f"Usuário com ID {id} não encontrado!")

    ler_salvar_arquivo(ler=False, nome_arquivo='projetoModuloII.json', cadastros=cadastros)
    return cadastros

# Função 5 - Exibe informações do usuário:
def exibir_usuario(cadastros, id):
    if str(id) in cadastros and cadastros[str(id)]['Status']:
        usuario = cadastros[str(id)]
        print(f"Nome: {usuario['Nome']}")
        print(f"Telefone: {usuario['Telefone']}")
        print(f"Endereço: {usuario['Endereço']}")
    else:
        print("Usuário não encontrado!")

# Função 6 - Exibe informações de todos os usuários ativos:
def exibir_todos_usuarios(cadastros):
    for usuario_id, usuario in cadastros.items():
        if usuario['Status']:
            print(f"ID: {usuario_id}")
            print(f"Nome: {usuario['Nome']}")
            print(f"Telefone: {usuario['Telefone']}")
            print(f"Endereço: {usuario['Endereço']}")
            print()

# Função Principal que implementa o loop do menu.
# Dependendo da opção escolhida, chama as funções apropriadas para realizar operações no cadastro.

def main():
    cadastros = ler_salvar_arquivo()

    while True:
        print(menu_principal)
        opcao = int(input("Informe o número da opção desejada: "))

        if opcao == 1:
            n = int(input("Informe o número de cadastros que deseja inserir: "))
            for _ in range(n):
                nome = input("Insira o nome: ")
                telefone = input("Insira o telefone: ")
                endereco = input("Insira o endereço: ")
                cadastros = add_usuario(cadastros, nome, telefone, endereco)
            ler_salvar_arquivo(ler=False, nome_arquivo='projetoModuloII.json', cadastros=cadastros)

        elif opcao == 2:
            ids = [int(id) for id in input("Insira o(s) ID(s) do(s) usuário(s) que deseja excluir (separados por espaço): ").split()]
            cadastros = excluir_usuario(cadastros, *ids)
            ler_salvar_arquivo(ler=False, nome_arquivo='projetoModuloII.json', cadastros=cadastros)

        elif opcao == 3:
            id_usuario = int(input("Insira o ID do usuário que deseja atualizar: "))
            print(sub_menu_principal)
            campo = int(input("Digite a opção desejada: "))
            novo_valor = input(f"Insira o novo valor para o campo selecionado: ")
            cadastros = editar_usuario(cadastros, id_usuario, campo, novo_valor)
            ler_salvar_arquivo(ler=False, nome_arquivo='projetoModuloII.json', cadastros=cadastros)

        elif opcao == 4:
            id_usuario = int(input("Insira o ID do usuário que deseja exibir: "))
            exibir_usuario(cadastros, id_usuario)

        elif opcao == 5:
            exibir_todos_usuarios(cadastros)

        elif opcao == 6:
            ler_salvar_arquivo(ler=False, nome_arquivo='projetoModuloII.json', cadastros=cadastros)
            print("Programa encerrado.")
            break

        else:
            print("Opção inválida!")

if __name__ == "__main__":
  main()

# %% [markdown]
# # 💻 Explicação do código

# %% [markdown]
# - Esse código em Python é um programa de gerenciamento de cadastros de usuários que utiliza um arquivo JSON para armazenar as informações dos usuários.
#
# - Oferece funcionalidades básicas de gerenciamento de cadastros, como adição, exclusão, edição e visualização de usuários. Os dados são armazenados e recuperados de um arquivo JSON para persistência entre diferentes execuções do programa.
#
# ### 🔶 Explicação de cada parte do código:
#
# 1. **Menu e Submenu:**
#    - `menu_str` e `sub_menu_str` são strings que representam o menu principal e o submenu do programa. Eles são utilizados para exibir opções ao usuário.
#
# 2. **Função `ler_salvar_arquivo`:**
#    - Esta função lê ou salva informações em um arquivo JSON.
#    - Se `ler` for `True`, ela tenta abrir o arquivo para leitura e carrega os dados do arquivo JSON usando `json.load()`. Se o arquivo não existir, retorna um dicionário vazio.
#    - Se `ler` for `False`, ela abre o arquivo para escrita (`'w'`) e salva os dados usando `json.dump()`.
#
# 3. **Função `add_usuario`:**
#    - Adiciona um novo usuário aos cadastros. Se um usuário com o mesmo nome, telefone e endereço já existir e estiver inativo, ativa esse usuário. Caso contrário, cria um novo usuário.
#
# 4. **Função `excluir_usuario`:**
#    - Marca usuários como inativos com base nos IDs fornecidos.
#
# 5. **Função `editar_usuario`:**
#    - Edita as informações de um usuário com base no ID, campo (nome, telefone, endereço) e novo valor fornecidos.
#
# 6. **Função `exibir_usuario`:**
#    - Exibe informações de um usuário com base no ID fornecido.
#
# 7. **Função `exibir_todos_usuarios`:**
#    - Exibe informações de todos os usuários ativos.
#
# 8. **Função `main`:**
#    - Função principal que implementa o loop do menu. O programa continua executando até que o usuário escolha a opção 6 para sair.
#    - Dependendo da opção escolhida, chama as funções apropriadas para realizar operações no cadastro.
#
# 9. **Bloco `if __name__ == "__main__":`**
#    - Garante que o programa seja executado apenas quando o script é executado diretamente, não quando é importado como um módulo.
